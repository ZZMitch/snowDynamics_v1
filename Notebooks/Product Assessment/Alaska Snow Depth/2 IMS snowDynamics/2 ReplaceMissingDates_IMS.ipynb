# %% [markdown]
# # Replace missing dates in IMS dataset
# - 2018: NA
# - 2019: NA
# - 2020: 1 day missing (May 12), from visualization will make copy of May 13
# - 2021: 2 days missing (Jan 2 and 3), from visualization will make Jan 2 a copy of Jan 1 and Jan 3 a copy of Jan 4
# - 2022: NA
# - 2023: NA

# %%
import pandas as pd

import sys
sys.path.append('C:/Users/mbonney/OneDrive - NRCan RNCan/Projects/UtilityCode/DataAccess/Utilities')
import PreProcess_Utils as pputil

sys.path.append('C:/Users/mbonney/OneDrive - NRCan RNCan/Projects/UtilityCode/Modelling/Utilities')
import Snow_Utils as snow_util

sys.path.append('C:/Users/mbonney/OneDrive - NRCan RNCan/Projects/UtilityCode/Visualization/Utilities')
import Viz_Utils as vutil

# %%
from dask.distributed import LocalCluster

cluster = LocalCluster(n_workers = 10, threads_per_worker = 10, memory_limit = 0) # Refined through testing
client = cluster.get_client()
client # Can open in other window by clicking 'Dashboard' link below
# Out:
# <Client: 'tcp://127.0.0.1:52848' processes=10 threads=100, memory=127.65 GiB>
# 2024-10-29 14:55:00,887 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,899 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,907 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,915 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,922 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,931 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,940 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,947 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,955 - distributed.nanny - WARNING - Restarting worker
# 2024-10-29 14:55:00,962 - distributed.nanny - WARNING - Restarting worker

# %% [markdown]
# ## 2020
# - Reindex (bfill May 13 to May 12)
# - Save full daily cube (will replace original)

# %%
# %%time
ims = pputil.uploadNC(r"C:\Users\mbonney\OneDrive - NRCan RNCan\Projects\Alaska\2 IMS\ims_nc\IMS_2020.nc", type = 'dataarray', chunks = {'time': 1, 'band': -1, 'x': -1, 'y': -1})
ims
# Out:
# CPU times: total: 125 ms
# Wall time: 1.21 s
# <xarray.DataArray (time: 365, y: 73, x: 47)> Size: 1MB
# dask.array<open_dataset-__xarray_dataarray_variable__, shape=(365, 73, 47), dtype=uint8, chunksize=(1, 73, 47), chunktype=numpy.ndarray>
# Coordinates:
#   * x            (x) float64 376B 4.002e+05 4.012e+05 ... 4.452e+05 4.462e+05
#   * y            (y) float64 584B 7.679e+06 7.678e+06 ... 7.608e+06 7.607e+06
#   * time         (time) datetime64[ns] 3kB 2020-01-01 2020-01-02 ... 2020-12-31
#     variable     <U18 72B ...
#     spatial_ref  int64 8B ...
# Attributes: (12/50)
#     _FillValue:                 0
#     Conventions:                CF-1.6, ACDD-1.3
#     title:                      NOAA/NESDIS Interactive Multisensor Snow and ...
#     summary:                    This file contains a map of snow cover and ic...
#     keywords:                   EARTH SCIENCE > CRYOSPHERE > SEA ICE > ICE EX...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Ke...
#     ...                         ...
#     metadata_link:              https://nsidc.org/data/G02156
#     naming_authority:           org.nsidc
#     references:                 Ramsay, B. H. (1998). The interactive multise...
#     history:                    23 July 2021 19:37Z: NetCDF file generated fr...
#     source:                     Analysts at the United States National Ice Ce...
#     comment:                    The IMS product has changed versions and reso...

# %%
time_index = pd.date_range(start = '01/01/2020', end = '12/31/2020') # All Days possible in cube
time_index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
# %%time
ims = ims.reindex({'time': time_index}, method = 'bfill') # Take May 13 and apply back to May 12
ims
# Out:
# CPU times: total: 0 ns
# Wall time: 21.1 ms
# <xarray.DataArray (time: 366, y: 73, x: 47)> Size: 1MB
# dask.array<getitem, shape=(366, 73, 47), dtype=uint8, chunksize=(2, 73, 47), chunktype=numpy.ndarray>
# Coordinates:
#   * x            (x) float64 376B 4.002e+05 4.012e+05 ... 4.452e+05 4.462e+05
#   * y            (y) float64 584B 7.679e+06 7.678e+06 ... 7.608e+06 7.607e+06
#   * time         (time) datetime64[ns] 3kB 2020-01-01 2020-01-02 ... 2020-12-31
#     variable     <U18 72B ...
#     spatial_ref  int64 8B ...
# Attributes: (12/50)
#     _FillValue:                 0
#     Conventions:                CF-1.6, ACDD-1.3
#     title:                      NOAA/NESDIS Interactive Multisensor Snow and ...
#     summary:                    This file contains a map of snow cover and ic...
#     keywords:                   EARTH SCIENCE > CRYOSPHERE > SEA ICE > ICE EX...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Ke...
#     ...                         ...
#     metadata_link:              https://nsidc.org/data/G02156
#     naming_authority:           org.nsidc
#     references:                 Ramsay, B. H. (1998). The interactive multise...
#     history:                    23 July 2021 19:37Z: NetCDF file generated fr...
#     source:                     Analysts at the United States National Ice Ce...
#     comment:                    The IMS product has changed versions and reso...

# %%
# %%time
load = pputil.loadXR(ims[130:135,:,:])
load
# Out:
# CPU times: total: 312 ms
# Wall time: 2.77 s
# <xarray.DataArray (time: 5, y: 73, x: 47)> Size: 17kB
# array([[[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 2, 2, 2],
#         [4, 4, 4, ..., 2, 2, 2],
#         [2, 4, 4, ..., 2, 2, 2]],
#
#        [[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 2, 2, 2],
#         [4, 4, 4, ..., 2, 2, 2],
#         [2, 4, 4, ..., 2, 2, 2]],
#
#        [[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 2, 2, 2],
#         [4, 4, 4, ..., 2, 2, 2],
#         [2, 4, 4, ..., 2, 2, 2]],
#
#        [[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 2, 2, 2],
#         [4, 4, 4, ..., 2, 2, 2],
#         [2, 4, 4, ..., 2, 2, 2]],
#
#        [[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 2, 2, 2],
#         [4, 4, 4, ..., 2, 2, 2],
#         [2, 4, 4, ..., 2, 2, 2]]], dtype=uint8)
# Coordinates:
#   * x            (x) float64 376B 4.002e+05 4.012e+05 ... 4.452e+05 4.462e+05
#   * y            (y) float64 584B 7.679e+06 7.678e+06 ... 7.608e+06 7.607e+06
#   * time         (time) datetime64[ns] 40B 2020-05-10 2020-05-11 ... 2020-05-14
#     variable     <U18 72B 'IMS_Surface_Values'
#     spatial_ref  int64 8B 0
# Attributes: (12/50)
#     _FillValue:                 0
#     Conventions:                CF-1.6, ACDD-1.3
#     title:                      NOAA/NESDIS Interactive Multisensor Snow and ...
#     summary:                    This file contains a map of snow cover and ic...
#     keywords:                   EARTH SCIENCE > CRYOSPHERE > SEA ICE > ICE EX...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Ke...
#     ...                         ...
#     metadata_link:              https://nsidc.org/data/G02156
#     naming_authority:           org.nsidc
#     references:                 Ramsay, B. H. (1998). The interactive multise...
#     history:                    23 July 2021 19:37Z: NetCDF file generated fr...
#     source:                     Analysts at the United States National Ice Ce...
#     comment:                    The IMS product has changed versions and reso...

# %%
# %%time
vutil.matrixPlot(load, sat = '', type = 'ims')
# Out:
# ---------------------------------------------------------------------------------------------------------------------------
# Water = Dark Blue | Land = Dark Green | Ice = Light Blue | Snow = Gray
# Outside ROI = White
# ---------------------------------------------------------------------------------------------------------------------------
# CPU times: total: 172 ms
# Wall time: 1.21 s

# %%
# %%time
# Save updated annual IMS cube
pputil.downloadNC(ims, r'C:\Users\mbonney\OneDrive - NRCan RNCan\Projects\Alaska\2 IMS\ims_nc', 'IMS_2020_1.nc', type = '')
# Out:
# CPU times: total: 4.52 s
# Wall time: 38.7 s

# %% [markdown]
# ## 2021
# - Reindex (nearest to fill in consecutivie missing Jan dates)
# - Save full daily cube (will replace original)

# %%
# %%time
ims = pputil.uploadNC(r"C:\Users\mbonney\OneDrive - NRCan RNCan\Projects\Alaska\2 IMS\ims_nc\IMS_2021.nc", type = 'dataarray', chunks = {'time': 1, 'band': -1, 'x': -1, 'y': -1})
ims
# Out:
# CPU times: total: 0 ns
# Wall time: 30.6 ms
# <xarray.DataArray (time: 363, y: 73, x: 47)> Size: 1MB
# dask.array<open_dataset-__xarray_dataarray_variable__, shape=(363, 73, 47), dtype=uint8, chunksize=(1, 73, 47), chunktype=numpy.ndarray>
# Coordinates:
#   * x            (x) float64 376B 4.002e+05 4.012e+05 ... 4.452e+05 4.462e+05
#   * y            (y) float64 584B 7.679e+06 7.678e+06 ... 7.608e+06 7.607e+06
#   * time         (time) datetime64[ns] 3kB 2021-01-01 2021-01-04 ... 2021-12-31
#     variable     <U18 72B ...
#     spatial_ref  int64 8B ...
# Attributes: (12/50)
#     _FillValue:                 0
#     Conventions:                CF-1.6, ACDD-1.3
#     title:                      NOAA/NESDIS Interactive Multisensor Snow and ...
#     summary:                    This file contains a map of snow cover and ic...
#     keywords:                   EARTH SCIENCE > CRYOSPHERE > SEA ICE > ICE EX...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Ke...
#     ...                         ...
#     metadata_link:              https://nsidc.org/data/G02156
#     naming_authority:           org.nsidc
#     references:                 Ramsay, B. H. (1998). The interactive multise...
#     history:                    26 July 2021 19:50Z: NetCDF file generated fr...
#     source:                     Analysts at the United States National Ice Ce...
#     comment:                    The IMS product has changed versions and reso...

# %%
time_index = pd.date_range(start = '01/01/2021', end = '12/31/2021') # All Days possible in cube
time_index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10',
#                ...
#                '2021-12-22', '2021-12-23', '2021-12-24', '2021-12-25',
#                '2021-12-26', '2021-12-27', '2021-12-28', '2021-12-29',
#                '2021-12-30', '2021-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
# %%time
ims = ims.reindex({'time': time_index}, method = 'nearest') # Jan 2 = Jan 1, Jan 3 = Jan 4
ims
# Out:
# CPU times: total: 0 ns
# Wall time: 7.46 ms
# <xarray.DataArray (time: 365, y: 73, x: 47)> Size: 1MB
# dask.array<getitem, shape=(365, 73, 47), dtype=uint8, chunksize=(2, 73, 47), chunktype=numpy.ndarray>
# Coordinates:
#   * x            (x) float64 376B 4.002e+05 4.012e+05 ... 4.452e+05 4.462e+05
#   * y            (y) float64 584B 7.679e+06 7.678e+06 ... 7.608e+06 7.607e+06
#   * time         (time) datetime64[ns] 3kB 2021-01-01 2021-01-02 ... 2021-12-31
#     variable     <U18 72B ...
#     spatial_ref  int64 8B ...
# Attributes: (12/50)
#     _FillValue:                 0
#     Conventions:                CF-1.6, ACDD-1.3
#     title:                      NOAA/NESDIS Interactive Multisensor Snow and ...
#     summary:                    This file contains a map of snow cover and ic...
#     keywords:                   EARTH SCIENCE > CRYOSPHERE > SEA ICE > ICE EX...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Ke...
#     ...                         ...
#     metadata_link:              https://nsidc.org/data/G02156
#     naming_authority:           org.nsidc
#     references:                 Ramsay, B. H. (1998). The interactive multise...
#     history:                    26 July 2021 19:50Z: NetCDF file generated fr...
#     source:                     Analysts at the United States National Ice Ce...
#     comment:                    The IMS product has changed versions and reso...

# %%
# %%time
load = pputil.loadXR(ims[0:5,:,:])
load
# Out:
# CPU times: total: 0 ns
# Wall time: 91.1 ms
# <xarray.DataArray (time: 5, y: 73, x: 47)> Size: 17kB
# array([[[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4]],
#
#        [[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4]],
#
#        [[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4]],
#
#        [[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4]],
#
#        [[4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         ...,
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4],
#         [4, 4, 4, ..., 4, 4, 4]]], dtype=uint8)
# Coordinates:
#   * x            (x) float64 376B 4.002e+05 4.012e+05 ... 4.452e+05 4.462e+05
#   * y            (y) float64 584B 7.679e+06 7.678e+06 ... 7.608e+06 7.607e+06
#   * time         (time) datetime64[ns] 40B 2021-01-01 2021-01-02 ... 2021-01-05
#     variable     <U18 72B 'IMS_Surface_Values'
#     spatial_ref  int64 8B 0
# Attributes: (12/50)
#     _FillValue:                 0
#     Conventions:                CF-1.6, ACDD-1.3
#     title:                      NOAA/NESDIS Interactive Multisensor Snow and ...
#     summary:                    This file contains a map of snow cover and ic...
#     keywords:                   EARTH SCIENCE > CRYOSPHERE > SEA ICE > ICE EX...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Ke...
#     ...                         ...
#     metadata_link:              https://nsidc.org/data/G02156
#     naming_authority:           org.nsidc
#     references:                 Ramsay, B. H. (1998). The interactive multise...
#     history:                    26 July 2021 19:50Z: NetCDF file generated fr...
#     source:                     Analysts at the United States National Ice Ce...
#     comment:                    The IMS product has changed versions and reso...

# %%
# %%time
vutil.matrixPlot(load, sat = '', type = 'ims')
# Out:
# ---------------------------------------------------------------------------------------------------------------------------
# Water = Dark Blue | Land = Dark Green | Ice = Light Blue | Snow = Gray
# Outside ROI = White
# ---------------------------------------------------------------------------------------------------------------------------
# CPU times: total: 172 ms
# Wall time: 823 ms

# %%
# %%time
# Save updated annual IMS cube
pputil.downloadNC(ims,  r'C:\Users\mbonney\OneDrive - NRCan RNCan\Projects\Alaska\2 IMS\ims_nc', 'IMS_2021_1.nc', type = '')
# Out:
# CPU times: total: 2.64 s
# Wall time: 18.8 s

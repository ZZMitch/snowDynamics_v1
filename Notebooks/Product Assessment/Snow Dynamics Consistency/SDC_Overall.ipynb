# %% [markdown]
# # Look at correlation across all pixels

# %%
import rioxarray as rxr
import xarray as xr
import numpy as np
#import xrspatial as xrs

from scipy.stats import pearsonr

import matplotlib.pyplot as plt

# %%
from dask.distributed import LocalCluster
cluster = LocalCluster(n_workers = 10, threads_per_worker = 10, memory_limit = 0) # Refined through testing
client = cluster.get_client()
client # Can open in other window by clicking 'Dashboard' link below
# Out:
# <Client: 'tcp://127.0.0.1:59372' processes=10 threads=100, memory=127.65 GiB>
# 2024-10-21 12:48:33,606 - distributed.nanny - WARNING - Restarting worker
# 2024-10-21 12:48:33,681 - distributed.nanny - WARNING - Restarting worker

# %%
# hls_1823_mn = rxr.open_rasterio(r"C:\Users\mbonney\OneDrive - NRCan RNCan\Projects\HBL\TemporalSnow\Fmask_V1\Products2\interannual_roi\HLS_Fmask_snow_end_mn_1823_HBL3x3.tif", masked = True)
# hls_1823_mn

# %%
# hls_1823_bv = rxr.open_rasterio(r"C:\Users\mbonney\OneDrive - NRCan RNCan\Projects\HBL\TemporalSnow\Fmask_V1\Products2\interannual_roi\HLS_Fmask_snow_end_bv_1823_HBL3x3.tif", masked = True)
# hls_1823_bv

# %%
hls_2223 = rxr.open_rasterio(r"F:\HLS\HBL\Products\SnowDynamics\winterYear_roi\2223\HLS_Fmask_snow_end_winterYear2223_HBL.tif", masked = True, chunks = 'auto').squeeze()
hls_2223 = xrs.focal.mean(hls_2223) # 3x3 Focal mean
hls_2223
# Out:
# <xarray.DataArray 'mean' (y: 32000, x: 46000)> Size: 12GB
# dask.array<_trim, shape=(32000, 46000), dtype=float64, chunksize=(729, 46000), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 368kB -7.102e+04 -7.1e+04 ... 1.309e+06 1.309e+06
#   * y            (y) float64 256kB 1.135e+06 1.135e+06 ... 1.753e+05 1.753e+05
#     spatial_ref  int64 8B 0
# Attributes: (12/13)
#     AREA_OR_POINT:           Area
#     STATISTICS_COUNT:        437626315.0
#     STATISTICS_COVARIANCES:  133.6703249568787
#     STATISTICS_MAXIMUM:      230
#     STATISTICS_MEAN:         130.43342892606
#     STATISTICS_MEDIAN:       129.352941
#     ...                      ...
#     STATISTICS_SKIPFACTORX:  1
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       11.561588340573
#     scale_factor:            1.0
#     add_offset:              0.0
#     long_name:               snow_end

# %%
hls_2122 = rxr.open_rasterio(r"F:\HLS\HBL\Products\SnowDynamics\winterYear_roi\2122\HLS_Fmask_snow_end_winterYear2122_HBL.tif", masked = True, chunks = 'auto').squeeze()
hls_2122 = xrs.focal.mean(hls_2122) # 3x3 Focal mean
hls_2122
# Out:
# <xarray.DataArray 'mean' (y: 32000, x: 46000)> Size: 12GB
# dask.array<_trim, shape=(32000, 46000), dtype=float64, chunksize=(729, 46000), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 368kB -7.102e+04 -7.1e+04 ... 1.309e+06 1.309e+06
#   * y            (y) float64 256kB 1.135e+06 1.135e+06 ... 1.753e+05 1.753e+05
#     spatial_ref  int64 8B 0
# Attributes: (12/13)
#     AREA_OR_POINT:           Area
#     STATISTICS_COUNT:        437634046.0
#     STATISTICS_COVARIANCES:  107.792319731937
#     STATISTICS_MAXIMUM:      237
#     STATISTICS_MEAN:         131.03583166558
#     STATISTICS_MEDIAN:       128.854902
#     ...                      ...
#     STATISTICS_SKIPFACTORX:  1
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       10.382308015655
#     scale_factor:            1.0
#     add_offset:              0.0
#     long_name:               snow_end

# %%
hls_2021 = rxr.open_rasterio(r"F:\HLS\HBL\Products\SnowDynamics\winterYear_roi\2021\HLS_Fmask_snow_end_winterYear2021_HBL.tif", masked = True, chunks = 'auto').squeeze()
hls_2021 = xrs.focal.mean(hls_2021) # 3x3 Focal mean
hls_2021
# Out:
# <xarray.DataArray 'mean' (y: 32000, x: 46000)> Size: 12GB
# dask.array<_trim, shape=(32000, 46000), dtype=float64, chunksize=(729, 46000), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 368kB -7.102e+04 -7.1e+04 ... 1.309e+06 1.309e+06
#   * y            (y) float64 256kB 1.135e+06 1.135e+06 ... 1.753e+05 1.753e+05
#     spatial_ref  int64 8B 0
# Attributes: (12/13)
#     AREA_OR_POINT:           Area
#     STATISTICS_COUNT:        436925940.0
#     STATISTICS_COVARIANCES:  358.3837979488593
#     STATISTICS_MAXIMUM:      231
#     STATISTICS_MEAN:         125.75298325399
#     STATISTICS_MEDIAN:       124.898039
#     ...                      ...
#     STATISTICS_SKIPFACTORX:  1
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       18.931027387568
#     scale_factor:            1.0
#     add_offset:              0.0
#     long_name:               snow_end

# %%
hls_1920 = rxr.open_rasterio(r"F:\HLS\HBL\Products\SnowDynamics\winterYear_roi\1920\HLS_Fmask_snow_end_winterYear1920_HBL.tif", masked = True, chunks = 'auto').squeeze()
hls_1920 = xrs.focal.mean(hls_1920) # 3x3 Focal mean
hls_1920
# Out:
# <xarray.DataArray 'mean' (y: 32000, x: 46000)> Size: 12GB
# dask.array<_trim, shape=(32000, 46000), dtype=float64, chunksize=(729, 46000), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 368kB -7.102e+04 -7.1e+04 ... 1.309e+06 1.309e+06
#   * y            (y) float64 256kB 1.135e+06 1.135e+06 ... 1.753e+05 1.753e+05
#     spatial_ref  int64 8B 0
# Attributes: (12/13)
#     AREA_OR_POINT:           Area
#     STATISTICS_COUNT:        437608538.0
#     STATISTICS_COVARIANCES:  126.3395326119207
#     STATISTICS_MAXIMUM:      236
#     STATISTICS_MEAN:         142.34371252057
#     STATISTICS_MEDIAN:       140.0
#     ...                      ...
#     STATISTICS_SKIPFACTORX:  1
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       11.240085969952
#     scale_factor:            1.0
#     add_offset:              0.0
#     long_name:               snow_end

# %%
hls_1819 = rxr.open_rasterio(r"F:\HLS\HBL\Products\SnowDynamics\winterYear_roi\1819\HLS_Fmask_snow_end_winterYear1819_HBL.tif", masked = True, chunks = 'auto').squeeze()
hls_1819 = xrs.focal.mean(hls_1819) # 3x3 Focal mean
hls_1819
# Out:
# <xarray.DataArray 'mean' (y: 32000, x: 46000)> Size: 12GB
# dask.array<_trim, shape=(32000, 46000), dtype=float64, chunksize=(729, 46000), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 368kB -7.102e+04 -7.1e+04 ... 1.309e+06 1.309e+06
#   * y            (y) float64 256kB 1.135e+06 1.135e+06 ... 1.753e+05 1.753e+05
#     spatial_ref  int64 8B 0
# Attributes: (12/14)
#     TIFFTAG_SOFTWARE:        GDAL 3.7.0e (3070046) (4.5.1;1700;3.0.0;2.0.7;;;...
#     AREA_OR_POINT:           Area
#     STATISTICS_COUNT:        437623483.0
#     STATISTICS_COVARIANCES:  197.4241244999606
#     STATISTICS_MAXIMUM:      235
#     STATISTICS_MEAN:         132.44826902724
#     ...                      ...
#     STATISTICS_SKIPFACTORX:  1
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       14.050769534085
#     scale_factor:            1.0
#     add_offset:              0.0
#     long_name:               snow_end

# %%
yr1 = hls_1819
yr2 = hls_1920

# %%
# %%time
print('From xarray: ' + str(xr.corr(yr1, yr2, dim = ['x', 'y']).load().item()))
# Out:
# From xarray: 0.6649450434862814
# CPU times: total: 16.1 s
# Wall time: 36.2 s

# %%
# %%time
# If null in either arr, set to null in both
yr1 = xr.where((yr2.isnull() | yr1.isnull()), np.nan, yr1)
yr2 = xr.where((yr2.isnull() | yr1.isnull()), np.nan, yr2)

# Flatten
yr1 = yr1.to_numpy().flatten()
yr2 = yr2.to_numpy().flatten()

# Drop null
yr1 = yr1[~np.isnan(yr1)]
yr2 = yr2[~np.isnan(yr2)]

print('From scipy:' + str(pearsonr(yr1, yr2)[0]) + ', pval: ' + str(pearsonr(yr1, yr2)[1]))
# Out:
# From scipy:0.7332140370372608, pval: 0.0
# CPU times: total: 3min 28s
# Wall time: 4min 32s

# %%
#plt.scatter(x = hls_2122, y = hls_2223) # Take a few minutes

# %%
# Heatmap?
#https://stackoverflow.com/questions/2369492/generate-a-heatmap-using-a-scatter-data-set

# %%
#len(yr1)

# %%
#len(yr2)

# %%
# For the best one, run scipy version and then this... 
heatmap, xedges, yedges = np.histogram2d(x = yr1, y = yr2, bins = 100)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

# %%
#plt.clf()
plt.imshow(heatmap.T, extent = extent, origin='lower', vmin = 0, vmax = 10000)

plt.show()

# %%
import statistics
cors = [0.79, 0.72, 0.78, 0.71, 0.81, 0.70, 0.82, 0.69, 0.81, 0.79, 0.82, 0.61, 0.70, 0.53, 0.60, 0.68, 0.87, 0.66, 0.31, 0.81]
statistics.mean(cors)
# Out:
# 0.7105

# %%
weights = [65, 65, 65, 65, 36, 36, 36, 36, 34, 34, 34, 34, 138, 138, 138, 138, 121, 121, 121, 121]

# %%
import numpy as np
np.average(cors, weights = weights)
# Out:
# np.float64(0.6813261421319797)
